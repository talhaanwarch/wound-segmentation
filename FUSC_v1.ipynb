# %% [markdown]
# <a href="https://colab.research.google.com/github/talhaanwarch/wound-segmentation/blob/master/FUSC_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#download data
# !git clone https://github.com/talhaanwarch/wound-segmentation.git
# Out:
# Cloning into 'wound-segmentation'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 2599 (delta 6), reused 2 (delta 0), pack-reused 2584
# Receiving objects: 100% (2599/2599), 256.16 MiB | 40.23 MiB/s, done.
# Resolving deltas: 100% (938/938), done.
# Checking out files: 100% (1621/1621), done.

# %%
# %%capture
#install packages
# !pip install -U segmentation-models

# %%
#import packages
from tensorflow.keras.utils import normalize
import os
import cv2
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from glob import glob
from tensorflow import keras
import numpy as np

# %%
#explore data
image = Image.open('/content/wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/0011.png')
mask=   Image.open('/content/wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/0011.png')
fig,ax=plt.subplots(1,2,figsize=(10,15))
ax[0].imshow(image)
ax[0].set_title('Image')
ax[1].imshow(mask)
ax[0].set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %%
#get path of images and mask directories
train_image_path='/content/wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/images/'
train_mask_path='/content/wound-segmentation/data/Foot Ulcer Segmentation Challenge/train/labels/'

val_image_path='/content/wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/'
val_mask_path='/content/wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/'

# %%
#load paths of images and masks files
train_input_img_paths=[i for i in glob(train_image_path+'*.png')]
train_target_img_paths =[i for i in glob(train_mask_path+'*.png')]

val_input_img_paths=[i for i in glob(val_image_path+'*.png')]
val_target_img_paths =[i for i in glob(val_mask_path+'*.png')]
print(len(train_input_img_paths),len(val_input_img_paths))
# Out:
# 610 200

# %%
#create a data loader 
#credit: https://keras.io/examples/vision/oxford_pets_image_segmentation/
class DataLoader(keras.utils.Sequence):
    """Helper to iterate over the data (as Numpy arrays)."""

    def __init__(self, batch_size, img_size, input_img_paths, target_img_paths):
        self.batch_size = batch_size
        self.img_size = img_size
        self.input_img_paths = input_img_paths
        self.target_img_paths = target_img_paths

    def __len__(self):
        return len(self.target_img_paths) // self.batch_size

    def __getitem__(self, idx):
        """Returns tuple (input, target) correspond to batch #idx."""
        i = idx * self.batch_size
        batch_input_img_paths = self.input_img_paths[i : i + self.batch_size]
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size]
        x = []
        for j, path in enumerate(batch_input_img_paths):
            img = Image.open(path)
            img = img.resize(img_size)
            img=np.array(img)
            x.append(img)
        x=np.array(x)
        if self.target_img_paths is not None:
          y = []
          for j, path in enumerate(batch_target_img_paths):
              img = Image.open(path).convert('L')
              img = img.resize(img_size)
              img=np.array(img)/255
              y.append(np.expand_dims(img, 2))
          y=np.array(y)
              
          return x, y
        else:
          return x

# %%
#create unet architecture
#credit: https://github.com/bnsreenu/python_for_microscopists/blob/master/208-simple_multi_unet_model.py

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda



################################################################
def multi_unet_model(n_classes=4, IMG_HEIGHT=256, IMG_WIDTH=256, IMG_CHANNELS=1):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
     
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
     
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
     
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    #Expansive path 
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
     
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
     
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
     
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
     
    outputs = Conv2D(n_classes, (1, 1), activation='sigmoid')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    
    return model

# %%
#parameters
img_size=(512, 512)
model = multi_unet_model(n_classes=1,IMG_HEIGHT=img_size[0], IMG_WIDTH=img_size[1],IMG_CHANNELS=3)
epochs=50
batch_size=24

# %%
#load data to data loader in batch
train_gen = DataLoader(
    batch_size, img_size, train_input_img_paths, train_target_img_paths
)
val_gen = DataLoader(batch_size, img_size, val_input_img_paths, val_target_img_paths)

# %%
#compile the model
model.compile(optimizer="rmsprop", loss="binary_crossentropy",metrics=keras.metrics.MeanIoU(num_classes=2))

# %%
#train the model
model.fit(train_gen, epochs=epochs, validation_data=val_gen)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 70s 1s/step - loss: 17.8834 - mean_io_u: 0.4941 - val_loss: 0.1508 - val_mean_io_u: 0.4939
# Epoch 2/50
# 25/25 [==============================] - 25s 1s/step - loss: 0.1945 - mean_io_u: 0.4933 - val_loss: 0.0776 - val_mean_io_u: 0.4939
# Epoch 3/50
# 25/25 [==============================] - 25s 998ms/step - loss: 0.1139 - mean_io_u: 0.4932 - val_loss: 0.0739 - val_mean_io_u: 0.4939
# Epoch 4/50
# 25/25 [==============================] - 25s 990ms/step - loss: 0.1010 - mean_io_u: 0.4930 - val_loss: 0.0781 - val_mean_io_u: 0.4939
# Epoch 5/50
# 25/25 [==============================] - 25s 995ms/step - loss: 0.1342 - mean_io_u: 0.4939 - val_loss: 0.1296 - val_mean_io_u: 0.4939
# Epoch 6/50
# 25/25 [==============================] - 25s 996ms/step - loss: 0.0796 - mean_io_u: 0.4936 - val_loss: 0.0621 - val_mean_io_u: 0.4939
# Epoch 7/50
# 25/25 [==============================] - 25s 990ms/step - loss: 0.5329 - mean_io_u: 0.4933 - val_loss: 0.0704 - val_mean_io_u: 0.4939
# Epoch 8/50
# 25/25 [==============================] - 25s 992ms/step - loss: 0.0649 - mean_io_u: 0.4940 - val_loss: 0.0579 - val_mean_io_u: 0.4939
# Epoch 9/50
# 25/25 [==============================] - 25s 991ms/step - loss: 0.0829 - mean_io_u: 0.4942 - val_loss: 0.0564 - val_mean_io_u: 0.4939
# Epoch 10/50
# 25/25 [==============================] - 25s 995ms/step - loss: 0.0622 - mean_io_u: 0.4939 - val_loss: 0.0574 - val_mean_io_u: 0.4939
# Epoch 11/50
# 25/25 [==============================] - 25s 994ms/step - loss: 0.0764 - mean_io_u: 0.4941 - val_loss: 0.0708 - val_mean_io_u: 0.4939
# Epoch 12/50
# 25/25 [==============================] - 25s 991ms/step - loss: 0.0620 - mean_io_u: 0.4940 - val_loss: 0.0526 - val_mean_io_u: 0.4939
# Epoch 13/50
# 25/25 [==============================] - 25s 989ms/step - loss: 0.0577 - mean_io_u: 0.4939 - val_loss: 0.0816 - val_mean_io_u: 0.4939
# Epoch 14/50
# 25/25 [==============================] - 25s 988ms/step - loss: 0.0712 - mean_io_u: 0.4936 - val_loss: 0.0536 - val_mean_io_u: 0.4939
# Epoch 15/50
# 25/25 [==============================] - 25s 986ms/step - loss: 0.0889 - mean_io_u: 0.4932 - val_loss: 0.0518 - val_mean_io_u: 0.4939
# Epoch 16/50
# 25/25 [==============================] - 25s 987ms/step - loss: 0.0855 - mean_io_u: 0.4931 - val_loss: 0.0483 - val_mean_io_u: 0.4939
# Epoch 17/50
# 25/25 [==============================] - 25s 987ms/step - loss: 0.0568 - mean_io_u: 0.4937 - val_loss: 0.0496 - val_mean_io_u: 0.4939
# Epoch 18/50
# 25/25 [==============================] - 25s 990ms/step - loss: 0.0580 - mean_io_u: 0.4938 - val_loss: 0.0454 - val_mean_io_u: 0.4939
# Epoch 19/50
# 25/25 [==============================] - 25s 991ms/step - loss: 0.0685 - mean_io_u: 0.4935 - val_loss: 0.0470 - val_mean_io_u: 0.4939
# Epoch 20/50
# 25/25 [==============================] - 25s 993ms/step - loss: 0.0581 - mean_io_u: 0.4936 - val_loss: 0.0473 - val_mean_io_u: 0.4939
# Epoch 21/50
# 25/25 [==============================] - 25s 989ms/step - loss: 0.0569 - mean_io_u: 0.4935 - val_loss: 0.0462 - val_mean_io_u: 0.4939
# Epoch 22/50
# 25/25 [==============================] - 25s 985ms/step - loss: 0.0485 - mean_io_u: 0.4941 - val_loss: 0.0444 - val_mean_io_u: 0.4939
# Epoch 23/50
# 25/25 [==============================] - 25s 988ms/step - loss: 0.0491 - mean_io_u: 0.4937 - val_loss: 0.0427 - val_mean_io_u: 0.4939
# Epoch 24/50
# 25/25 [==============================] - 25s 986ms/step - loss: 0.0524 - mean_io_u: 0.4939 - val_loss: 0.0477 - val_mean_io_u: 0.4939
# Epoch 25/50
# 25/25 [==============================] - 25s 986ms/step - loss: 0.0477 - mean_io_u: 0.4938 - val_loss: 0.0984 - val_mean_io_u: 0.4939
# Epoch 26/50
# 25/25 [==============================] - 25s 990ms/step - loss: 0.0850 - mean_io_u: 0.4937 - val_loss: 0.0444 - val_mean_io_u: 0.4939
# Epoch 27/50
# 25/25 [==============================] - 25s 985ms/step - loss: 0.0469 - mean_io_u: 0.4938 - val_loss: 0.0396 - val_mean_io_u: 0.4939
# Epoch 28/50
# 25/25 [==============================] - 25s 985ms/step - loss: 0.0451 - mean_io_u: 0.4939 - val_loss: 0.0401 - val_mean_io_u: 0.4939
# Epoch 29/50
# 25/25 [==============================] - 25s 984ms/step - loss: 0.0457 - mean_io_u: 0.4938 - val_loss: 0.0455 - val_mean_io_u: 0.4939
# Epoch 30/50
# 25/25 [==============================] - 25s 987ms/step - loss: 0.0500 - mean_io_u: 0.4935 - val_loss: 0.0376 - val_mean_io_u: 0.4939
# Epoch 31/50
# 25/25 [==============================] - 25s 986ms/step - loss: 0.0458 - mean_io_u: 0.4936 - val_loss: 0.0582 - val_mean_io_u: 0.4939
# Epoch 32/50
# 25/25 [==============================] - 25s 986ms/step - loss: 0.0504 - mean_io_u: 0.4932 - val_loss: 0.0357 - val_mean_io_u: 0.4939
# Epoch 33/50
# 25/25 [==============================] - 25s 986ms/step - loss: 0.0449 - mean_io_u: 0.4942 - val_loss: 0.0393 - val_mean_io_u: 0.4939
# Epoch 34/50
# 25/25 [==============================] - 25s 987ms/step - loss: 0.0415 - mean_io_u: 0.4942 - val_loss: 0.0376 - val_mean_io_u: 0.4939
# Epoch 35/50
# 25/25 [==============================] - 25s 989ms/step - loss: 0.0403 - mean_io_u: 0.4935 - val_loss: 0.0352 - val_mean_io_u: 0.4939
# Epoch 36/50
# 25/25 [==============================] - 25s 988ms/step - loss: 0.0426 - mean_io_u: 0.4934 - val_loss: 0.0366 - val_mean_io_u: 0.4939
# Epoch 37/50
# 25/25 [==============================] - 25s 985ms/step - loss: 0.0414 - mean_io_u: 0.4935 - val_loss: 0.0425 - val_mean_io_u: 0.4939
# Epoch 38/50
# 25/25 [==============================] - 25s 987ms/step - loss: 0.0406 - mean_io_u: 0.4940 - val_loss: 0.0341 - val_mean_io_u: 0.4939
# Epoch 39/50
# 25/25 [==============================] - 25s 985ms/step - loss: 0.0400 - mean_io_u: 0.4930 - val_loss: 0.0341 - val_mean_io_u: 0.4939
# Epoch 40/50
# 25/25 [==============================] - 25s 985ms/step - loss: 0.0378 - mean_io_u: 0.4936 - val_loss: 0.0348 - val_mean_io_u: 0.4939
# Epoch 41/50
# 25/25 [==============================] - 25s 985ms/step - loss: 0.0386 - mean_io_u: 0.4933 - val_loss: 0.0341 - val_mean_io_u: 0.4939
# Epoch 42/50
# 25/25 [==============================] - 25s 985ms/step - loss: 0.0363 - mean_io_u: 0.4935 - val_loss: 0.0298 - val_mean_io_u: 0.4939
# Epoch 43/50
# 25/25 [==============================] - 25s 991ms/step - loss: 0.0368 - mean_io_u: 0.4938 - val_loss: 0.0330 - val_mean_io_u: 0.4939
# Epoch 44/50
# 25/25 [==============================] - 25s 983ms/step - loss: 0.0351 - mean_io_u: 0.4935 - val_loss: 0.0451 - val_mean_io_u: 0.4939
# Epoch 45/50
# 25/25 [==============================] - 25s 984ms/step - loss: 0.0355 - mean_io_u: 0.4931 - val_loss: 0.0278 - val_mean_io_u: 0.4939
# Epoch 46/50
# 25/25 [==============================] - 25s 985ms/step - loss: 0.0356 - mean_io_u: 0.4939 - val_loss: 0.0307 - val_mean_io_u: 0.4939
# Epoch 47/50
# 25/25 [==============================] - 25s 988ms/step - loss: 0.0321 - mean_io_u: 0.4940 - val_loss: 0.0298 - val_mean_io_u: 0.4939
# Epoch 48/50
# 25/25 [==============================] - 25s 987ms/step - loss: 0.0294 - mean_io_u: 0.4940 - val_loss: 0.0295 - val_mean_io_u: 0.4939
# Epoch 49/50
# 25/25 [==============================] - 25s 986ms/step - loss: 0.0319 - mean_io_u: 0.4942 - val_loss: 0.0270 - val_mean_io_u: 0.4939
# Epoch 50/50
# 25/25 [==============================] - 25s 986ms/step - loss: 0.0323 - mean_io_u: 0.4940 - val_loss: 0.0383 - val_mean_io_u: 0.4939

# %%
#get random image from val data and display the result
import random
test_img_number = random.randint(0, len(val_input_img_paths))
test_img = val_input_img_paths[test_img_number]
ground_truth=val_target_img_paths[test_img_number]
print(test_img)
print(ground_truth)
# Out:
# /content/wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/images/0657.png
# /content/wound-segmentation/data/Foot Ulcer Segmentation Challenge/validation/labels/0657.png

# %%
#resize image to be accepted by unet
test_img = Image.open(test_img)
test_img_resize =  test_img.resize(img_size)
print(test_img.size)
ground_truth = Image.open(ground_truth)
# Out:
# (512, 512)

# %%
#Predict the output mask
test_img_input=np.expand_dims(test_img_resize, 0)
prediction = model.predict(test_img_input)[0,:,:,:]
print(prediction.shape)
plt.imshow(prediction.squeeze(),cmap='gray')
# Out:
# (512, 512, 1)

# %%
#resize image
from skimage.transform import resize
pred_resize=resize(prediction,(test_img.size[1],test_img.size[0]))
plt.imshow(pred_resize.squeeze(),cmap='gray')

# %%
#display results
fig,ax=plt.subplots(1,3,figsize=(15,25))
ax[0].imshow(test_img)
ax[0].set_title('Image')
ax[1].imshow(ground_truth)
ax[1].set_title('Actual Mask')
ax[2].imshow(pred_resize.squeeze(),cmap='gray')
ax[2].set_title('Predicted Mask')
# Out:
# Text(0.5, 1.0, 'Predicted Mask')
